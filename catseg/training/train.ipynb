# %%
import os
from ultralytics import YOLO

# %%
model = YOLO('yolov8n-seg.pt')
# Out:
# ...
# 100%|██████████| 6.74M/6.74M [00:05<00:00, 1.36MB/s]

# %%
DIR = "E:/Projects/Catautoencoder/catseg/training/CatsSegmentation"
model.train(data=os.path.join(DIR, "data.yaml"), epochs=10, batch=16, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.56 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.53  Python-3.11.4 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
# ...
